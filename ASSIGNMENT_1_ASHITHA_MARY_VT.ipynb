# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Task No 1

# %%
#CREATING PANDAS DATAFRAME WITH NUMPY RANDOM VALUES

# %%
datas=pd.DataFrame(np.arange(25).reshape(5,5))
datas
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24

# %% [markdown]
# Task No -2

# %%
#renaming column names

# %%
datas.columns=['A','B','C','D','E']
datas
# Out:
#     A   B   C   D   E
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24

# %% [markdown]
# Task No -3

# %%
# Descriptive Statistics of datas data frame

# %%
datas.describe()
# Out:
#                A          B          C          D          E
# count   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   10.000000  11.000000  12.000000  13.000000  14.000000
# std     7.905694   7.905694   7.905694   7.905694   7.905694
# min     0.000000   1.000000   2.000000   3.000000   4.000000
# 25%     5.000000   6.000000   7.000000   8.000000   9.000000
# 50%    10.000000  11.000000  12.000000  13.000000  14.000000
# 75%    15.000000  16.000000  17.000000  18.000000  19.000000
# max    20.000000  21.000000  22.000000  23.000000  24.000000

# %% [markdown]
# Task No -4

# %%
#Checking for null values

# %%
datas.isnull().any()
# Out:
# A    False
# B    False
# C    False
# D    False
# E    False
# dtype: bool

# %%
#Checking datatype of the columns

# %%
datas.dtypes
# Out:
# A    int64
# B    int64
# C    int64
# D    int64
# E    int64
# dtype: object

# %% [markdown]
# Task No-5

# %%
#display random value 2 and 3 columns using iloc

# %%
datas.iloc[:,1:3]
# Out:
#     B   C
# 0   1   2
# 1   6   7
# 2  11  12
# 3  16  17
# 4  21  22

# %%
# Display random value 2 and 3 columns using loc

# %%
datas.loc[:,'B':'C']
# Out:
#     B   C
# 0   1   2
# 1   6   7
# 2  11  12
# 3  16  17
# 4  21  22
